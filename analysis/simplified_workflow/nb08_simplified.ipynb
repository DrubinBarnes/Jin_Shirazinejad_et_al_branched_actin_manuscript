# %% [markdown]
# Cyna Shirazinejad, 1/17/22
#
# # Notebook 8: compare cell lines
#
# outline:
#
# * compare the following attributes:
# * * principal component distributions
# * * maximum intensities
# * * lifetimes
# * * initiation rates of events

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt
import seaborn as sns
unique_user_saved_outputs = str(np.load('unique_user_saved_outputs_simplified.npy'))
analysis_metadata = np.load(unique_user_saved_outputs+'/dataframes/analysis_metadata.npy', allow_pickle=True)
sys.path.append(analysis_metadata.item().get('path_notebook')+'/cmeAnalysisPostProcessingSimplified') # add custom Python scripts to the local path
import compare_tracks
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ##### import all necessary Python modules

# %% [markdown]
# # upload DNM2 channels and calculate area of colonies (some cmeAnalysis masks are blank)

# %%
analysis_metadata.item().get('path_tracks

# %%
ad_tracks_cell_area = compare_tracks.calculate_fraction_area_occupied_by_cells(analysis_metadata.item().get('path_tracks_ad_wildtype'),
                                                         'Cell',
                                                         2,
                                                         imagesize=[512,512])
# Out:
# folders to mine:
# 200804_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell004_1s
# 200804_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell005_1s
# 200804_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell006_1s
# 200804_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell007_1s
# 200804_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell010_1s
# 200819_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell004_1s
# 200819_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell005_1s
# 200819_ap2-dnm2_ap2-dnm2_wildtype_no-treatment_Cell006_1s
# The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.

# %%
path_ada_tracks = '/Volumes/Google Drive/My Drive/Drubin Lab/ap2dynm2arcp3_project/tracking_data/ADA_cellline_analysis_formatted_temp/'

# %%
ada_tracks_cell_area = compare_tracks.calculate_fraction_area_occupied_by_cells(path_ada_tracks,
                                                         'Cell',
                                                         2,
                                                         imagesize=[512,512])
# Out:
# folders to mine:
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell001_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell002_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell003_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell004_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell005_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell001_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell002_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell003_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell008_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell009_1s
# 200819_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell001_1s
# 200819_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell002_1s
# 200819_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell003_1s

# %%
plt.hist(ad_tracks_cell_area+ada_tracks_cell_area)
plt.xlabel('fraction of field-of-view covered by cell colony')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
# ad experiments dataframe
df_merged_features = pd.read_csv(unique_user_saved_outputs+'/dataframes/df_merged_features.zip')
# ada experiments dataframe
df_ada_merged_features = pd.read_csv(unique_user_saved_outputs+'/dataframes/df_ada_merged_features.zip')

# %%
df_merged_features
# Out:
#        lifetime  max_int_ap2  max_int_dnm2  dist_traveled_ap2  \
# 0         216.0  1796.284550    740.516756           7.203812
# 1         201.0  2215.532695   1505.433273          17.220726
# 2         201.0   864.976087    421.405691          17.621866
# 3         192.0   509.795166    356.302521          10.804211
# 4         188.0  1636.422386    883.606436          11.255090
# ...         ...          ...           ...                ...
# 59234       2.0    28.623953     19.042675           1.879691
# 59235       2.0    15.164065     14.946216           7.447355
# 59236       2.0    21.879792     26.215772           4.384565
# 59237       2.0    20.236623     13.954595           1.079388
# 59238       2.0    31.736903     27.212507           2.379635
#
#        dist_traveled_dnm2  max_dist_between_ap2_dnm2    md_ap2   md_dnm2  \
# 0                7.203812                   2.630656  0.566262  0.725913
# 1               14.507135                   3.797526  0.424574  0.912671
# 2               17.130473                   3.472332  0.566588  0.776404
# 3               13.292842                   5.888569  0.428736  1.058177
# 4                7.793074                   5.531006  0.415792  0.753372
# ...                   ...                        ...       ...       ...
# 59234            2.915253                   2.389665  1.092336  1.354985
# 59235            2.666432                   6.454259  2.453558  1.923304
# 59236            1.665404                   4.318207  1.873770  2.418798
# 59237            2.888644                   3.897009  0.843483  2.105214
# 59238            4.108440                   5.030972  1.391066  1.382033
#
#        time_to_peak_ap2  time_to_peak_dnm2  ...  cell_line_tags  \
# 0                 159.0              186.0  ...        ap2-dnm2
# 1                 111.0              107.0  ...        ap2-dnm2
# 2                  42.0               44.0  ...        ap2-dnm2
# 3                  44.0              190.0  ...        ap2-dnm2
# 4                 174.0              169.0  ...        ap2-dnm2
# ...                 ...                ...  ...             ...
# 59234               6.0                0.0  ...        ap2-dnm2
# 59235               6.0                3.0  ...        ap2-dnm2
# 59236               6.0                6.0  ...        ap2-dnm2
# 59237               6.0               11.0  ...        ap2-dnm2
# 59238               5.0               10.0  ...        ap2-dnm2
#
#        current_tracked_channels  experiment_type  cell_condition  framerate  \
# 0                      ap2-dnm2         wildtype    no-treatment         1s
# 1                      ap2-dnm2         wildtype    no-treatment         1s
# 2                      ap2-dnm2         wildtype    no-treatment         1s
# 3                      ap2-dnm2         wildtype    no-treatment         1s
# 4                      ap2-dnm2         wildtype    no-treatment         1s
# ...                         ...              ...             ...        ...
# 59234                  ap2-dnm2         wildtype    no-treatment         1s
# 59235                  ap2-dnm2         wildtype    no-treatment         1s
# 59236                  ap2-dnm2         wildtype    no-treatment         1s
# 59237                  ap2-dnm2         wildtype    no-treatment         1s
# 59238                  ap2-dnm2         wildtype    no-treatment         1s
#
#          date       PC-0      PC-1  gmm_predictions  ccp_status
# 0      200804  10.331699 -6.965018                0         0.0
# 1      200804  10.538036 -6.055586                0         0.0
# 2      200804  10.313709 -4.689303                0         0.0
# 3      200804   9.514337 -6.369698                0         1.0
# 4      200804  11.067962 -5.938112                0         0.0
# ...       ...        ...       ...              ...         ...
# 59234  200819  -7.669158  6.592425                3         0.0
# 59235  200819  -6.806042  3.105412                3         0.0
# 59236  200819   2.012646  4.546745                2         0.0
# 59237  200819  -7.624608  1.478759                3         0.0
# 59238  200819  -6.194758  1.121486                3         0.0
#
# [59239 rows x 45 columns]

# %%
df_ada_merged_features
# Out:
#        lifetime  max_int_ap2  max_int_dnm2  dist_traveled_ap2  \
# 0         209.0  1013.148525    552.713933          19.933012
# 1         202.0   894.249101    548.768087          13.452952
# 2         199.0   920.902337    491.017736          11.149507
# 3         197.0  1522.927627   1472.756604           8.861619
# 4         196.0  1313.707712    695.651290           7.742960
# ...         ...          ...           ...                ...
# 95120       2.0    20.371898     14.543122           2.257600
# 95121       2.0    26.545835     18.728653           1.381754
# 95122       2.0    30.679552     25.954461           5.877021
# 95123       2.0    27.137146     25.832401           1.715235
# 95124       2.0    20.191605     16.443930           4.121103
#
#        dist_traveled_dnm2  max_dist_between_ap2_dnm2    md_ap2   md_dnm2  \
# 0               18.402473                   3.188439  0.361960  0.570035
# 1                9.520588                   5.468989  0.372285  0.850422
# 2                8.785578                   2.881277  0.231291  0.607379
# 3                7.629581                   3.036999  0.275162  0.611874
# 4               10.954841                   2.860498  0.219819  0.557288
# ...                   ...                        ...       ...       ...
# 95120            1.708728                   4.794535  1.340784  2.136954
# 95121            4.299297                   3.841336  2.128264  1.911551
# 95122            4.372818                   4.143621  1.489194  1.151058
# 95123            5.036993                   3.466281  1.797761  0.855427
# 95124            3.153574                   4.505754  1.963514  1.039720
#
#        time_to_peak_ap2  time_to_peak_dnm2  ...  cell_line_tags  \
# 0                 201.0              130.0  ...  ap2-dnm2-arpc3
# 1                 173.0              180.0  ...  ap2-dnm2-arpc3
# 2                 127.0              145.0  ...  ap2-dnm2-arpc3
# 3                 137.0              155.0  ...  ap2-dnm2-arpc3
# 4                 168.0               74.0  ...  ap2-dnm2-arpc3
# ...                 ...                ...  ...             ...
# 95120               5.0                7.0  ...  ap2-dnm2-arpc3
# 95121               5.0                0.0  ...  ap2-dnm2-arpc3
# 95122               5.0                7.0  ...  ap2-dnm2-arpc3
# 95123               5.0                6.0  ...  ap2-dnm2-arpc3
# 95124               5.0                7.0  ...  ap2-dnm2-arpc3
#
#        current_tracked_channels  experiment_type  cell_condition  framerate  \
# 0                      ap2-dnm2         wildtype    no-treatment         1s
# 1                      ap2-dnm2         wildtype    no-treatment         1s
# 2                      ap2-dnm2         wildtype    no-treatment         1s
# 3                      ap2-dnm2         wildtype    no-treatment         1s
# 4                      ap2-dnm2         wildtype    no-treatment         1s
# ...                         ...              ...             ...        ...
# 95120                  ap2-dnm2         wildtype    no-treatment         1s
# 95121                  ap2-dnm2         wildtype    no-treatment         1s
# 95122                  ap2-dnm2         wildtype    no-treatment         1s
# 95123                  ap2-dnm2         wildtype    no-treatment         1s
# 95124                  ap2-dnm2         wildtype    no-treatment         1s
#
#          date       PC-0      PC-1  gmm_predictions  ccp_status
# 0      200722  11.658500 -4.847125                0         0.0
# 1      200722  10.140844 -5.995235                0         0.0
# 2      200722   8.932092 -6.313098                0         0.0
# 3      200722  10.606080 -6.094837                0         0.0
# 4      200722   9.714568 -4.815369                0         0.0
# ...       ...        ...       ...              ...         ...
# 95120  200819  -6.842034  2.036463                3         0.0
# 95121  200819  -7.641205  6.935307                3         0.0
# 95122  200819  -6.231037  1.434207                3         0.0
# 95123  200819  -6.517433  1.967509                3         0.0
# 95124  200819  -6.596895  1.953444                3         0.0
#
# [95125 rows x 45 columns]

# %%
def compare_components_between_conditions(path_outputs,
                                          conditions,
                                          fraction_areas,
                                          normalization_factor):

    analysis_metadata = np.load(path_outputs+'/dataframes/analysis_metadata.npy', allow_pickle=True)
    number_of_clusters = analysis_metadata.item().get('number_of_clusters')
    
    exp_number_label = []
    cluster_label = []
    compiled_labels = []
    fraction_cluster_label = []
    rates = []
    
    for condition_number, current_condition in enumerate(conditions):
        
        for exp_index, exp_number in enumerate(set(current_condition['experiment_number'].values)):
            
            exp_number_label += [exp_number for _ in range(number_of_clusters)]
            cluster_label += list(range(number_of_clusters))
            compiled_labels += [condition_number for _ in range(number_of_clusters)]
            
            indices_experiment = current_condition[current_condition['experiment_number']==exp_number].index.values
            
            gmm_predictions_exp = current_condition['gmm_predictions'][indices_experiment].values
            
            for comp_number in range(number_of_clusters):
                
                num_in_comp = len(np.where(gmm_predictions_exp==comp_number)[0])
                fraction = num_in_comp/len(gmm_predictions_exp)
                fraction_cluster_label.append(fraction)
                rates.append(num_in_comp/fraction_areas[condition_number][exp_index]/normalization_factor)
                
    exp_number_label = np.array(exp_number_label).reshape(len(exp_number_label), -1).astype(np.float)
    cluster_label = np.array(cluster_label).reshape(len(exp_number_label), -1).astype(np.float)
    fraction_cluster_label = np.array(fraction_cluster_label).reshape(len(exp_number_label), -1).astype(np.float)
    compiled_labels = np.array(compiled_labels).reshape(len(exp_number_label), -1)
    rates = np.array(rates).reshape(len(exp_number_label), -1)
    
    data_df = np.hstack((exp_number_label, 
                         cluster_label, 
                         fraction_cluster_label, 
                         rates,
                         compiled_labels))
    df_fraction_comps_between_experiments = pd.DataFrame(data=data_df, columns=['experiment_number', 
                                                                                'component_number', 
                                                                                'fraction', 
                                                                                'rates',
                                                                                'condition'])        
    
    return df_fraction_comps_between_experiments

# %%
df_comp_fractions = compare_components_between_conditions(
                        unique_user_saved_outputs,
                        [df_merged_features, 
                         df_ada_merged_features],
                        [ad_tracks_cell_area,
                         ada_tracks_cell_area],
                         .108*.108*512*512*4)

# %%
df_comp_fractions
# Out:
#      experiment_number  component_number  fraction     rates  condition
# 0                  0.0               0.0  0.088948  0.060863        0.0
# 1                  0.0               1.0  0.245672  0.168103        0.0
# 2                  0.0               2.0  0.112916  0.077264        0.0
# 3                  0.0               3.0  0.164581  0.112615        0.0
# 4                  0.0               4.0  0.387883  0.265412        0.0
# ..                 ...               ...       ...       ...        ...
# 100               20.0               0.0  0.082115  0.049604        1.0
# 101               20.0               1.0  0.239717  0.144807        1.0
# 102               20.0               2.0  0.106373  0.064257        1.0
# 103               20.0               3.0  0.187434  0.113224        1.0
# 104               20.0               4.0  0.384360  0.232182        1.0
#
# [105 rows x 5 columns]

# %%
g = sns.stripplot(data=df_comp_fractions,
                  x='component_number',
                  y='fraction',
                  hue='condition',
                  dodge=False)
plt.ylim(0,0.5)
# Out:
# (0.0, 0.5)

# %%
g = sns.stripplot(data=df_comp_fractions,
                  x='component_number',
                  y='fraction',
                  hue='condition',
                  dodge=True)

# %%
df_merged_features = pd.read_csv('/Users/cynashirazinejad/Desktop/test7.zip')

# %%
df_comp_fractions
# Out:
#      experiment_number  component_number  fraction     rates  condition
# 0                  0.0               0.0  0.088948  0.060863        0.0
# 1                  0.0               1.0  0.245672  0.168103        0.0
# 2                  0.0               2.0  0.112916  0.077264        0.0
# 3                  0.0               3.0  0.164581  0.112615        0.0
# 4                  0.0               4.0  0.387883  0.265412        0.0
# ..                 ...               ...       ...       ...        ...
# 100               20.0               0.0  0.082115  0.049604        1.0
# 101               20.0               1.0  0.239717  0.144807        1.0
# 102               20.0               2.0  0.106373  0.064257        1.0
# 103               20.0               3.0  0.187434  0.113224        1.0
# 104               20.0               4.0  0.384360  0.232182        1.0
#
# [105 rows x 5 columns]

# %%
df_merged_features
# Out:
#      experiment_number  component_number      rate  number_of_channels
# 0                  0.0               0.0  0.061291                 2.0
# 1                  0.0               1.0  0.169284                 2.0
# 2                  0.0               2.0  0.077806                 2.0
# 3                  0.0               3.0  0.113407                 2.0
# 4                  0.0               4.0  0.267276                 2.0
# ..                 ...               ...       ...                 ...
# 100               20.0               0.0  0.046539                 3.0
# 101               20.0               1.0  0.144492                 3.0
# 102               20.0               2.0  0.067141                 3.0
# 103               20.0               3.0  0.100252                 3.0
# 104               20.0               4.0  0.218715                 3.0
#
# [105 rows x 4 columns]

# %%
g = sns.stripplot(data=df_comp_fractions,
                  x='component_number',
                  y='df_merged_features = pd.read_csv(unique_user_saved_outputs+'/dataframes/df_merged_features.zip')
rates',
                  hue='condition')
plt.ylim(0,0.5)
# Out:
# (0.0, 0.5)

# %%
def convert_fractions_to_rates(dataframe_fractions, 
                               fraction_area,
                               normalization_factor):
    
    df_copy = dataframe_fractions.copy()
    
    rates = []
    
    for exp_num in range(len(fraction_area)):
        
        indices_exp = df_copy[df_copy['experiment_number']==exp_num].index.values
        fractions_components_experiment = df_copy['fraction'].values[indices_exp]
        
        rates_exp = fractions_components_experiment/fraction_area[exp_num]/normalization_factor
        
        rates += rates[]
