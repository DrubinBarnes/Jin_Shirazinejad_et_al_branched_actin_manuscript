# %% [markdown]
# Cyna Shirazinejad, 1/13/22
#
# # outline of notebook 7:
#
# * load data from cell lines:
# * * AP2-tagRFP-T, tagGFP2-DNM2, ARPC3-HaloTag
# * * AP2-tagRFP-T, tagGFP2-DNM2, N-WASP-HaloTag
# * extract features from tracks
# * * use existing feature scaler, decomposition axes, and mixture model to predict the identity of each new event
# * merge the new data with existing tracks, features, and model cluster identities

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import pandas as pd
import sys
unique_user_saved_outputs = str(np.load('unique_user_saved_outputs_simplified.npy'))
analysis_metadata = np.load(unique_user_saved_outputs+'/dataframes/analysis_metadata.npy', allow_pickle=True)
sys.path.append(analysis_metadata.item().get('path_notebook')+'/cmeAnalysisPostProcessingPythonScripts') # add custom Python scripts to the local path
import display_tracks
import detect_peaks

# %%
display_tracks.upload_tracks_and_metadata?
# Out:
# Signature:
# display_tracks.upload_tracks_and_metadata(
#     path_tracks,
#     path_outputs,
#     analysis_metadata,
#     track_categories,
#     identifier_string,
#     features,
#     labels,
#     experiment_number_adjustment=0,
#     dataframe_name='df_merged_features',
# )
# Docstring:
# Format tracks contained in folders into a dataframe of extracted physical features
# as well as accompanying experimental metadata.
#
# Args:
#     analysis_metadata (dictionary): contains path to the folder containing the enclosed tracking files and output files
#     track_categories (list): a list of integers for the cmeAnalysis track categories to keep for further analysis
#     identifier_string (string): a label within all tracking head folders that uniquely identify relevant content
#     features (list): a list with string elements containing the features to be extracted from each track
#     labels (list): a list of string elements describing each features' designation in the dataframe output
#     experiment_number_adjustment (int): a number to offset the starting cout for experiment number, nonzero if data is to be
#         appended to another existing dataset
#
# Returns:
#
#     df (dataframe): a dataframe of features and metadata
#     merged_all_tracks (ndarray):
# File:      ~/Documents/GitHub/Jin_Shirazinejad_et_al_branched_actin_manuscript/analysis/cmeAnalysisPostProcessingPythonScripts/display_tracks.py
# Type:      function

# %%
df_merged_features = pd.read_csv(unique_user_saved_outputs+'/dataframes/df_merged_features.zip')

# %%
max_experiment_number = df_merged_features['experiment_number'].max()

# %%
max_experiment_number
# Out:
# 7.0

# %%
possible_track_features = analysis_metadata.item().get('possible_track_features')
possible_track_features_labels = analysis_metadata.item().get('possible_track_features_labels')

# %%
path_ada_tracks = '/Volumes/Google Drive/My Drive/Drubin Lab/ap2dynm2arcp3_project/tracking_data/ADA_cellline_analysis_formatted_temp/'

# %%
df_ada_merged_features, merged_all_valid_ada_tracks = display_tracks.upload_tracks_and_metadata(
                                                               path_ada_tracks,  
                                                               analysis_metadata.item().get('path_outputs'),
                                                               analysis_metadata,
                                                               [1],
                                                               'Cell',
                                                               possible_track_features,
                                                               possible_track_features_labels,
                                                               'df_ada_merged_features',
                                                               'merged_all_valid_ada_tracks',
                                                               experiment_number_adjustment=max_experiment_number+1)
# Out:
# folders to mine:
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell001_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell002_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell003_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell004_1s
# 200722_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell005_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell001_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell002_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell003_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell008_1s
# 200804_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell009_1s
# 200819_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell001_1s
# 200819_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell002_1s
# 200819_ap2-dnm2-arpc3_ap2-dnm2_wildtype_no-treatment_Cell003_1s
#
#
# The number of tracks returned: 7668
#
# The number of tracks returned: 7709
#
# The number of tracks returned: 7431
#
# The number of tracks returned: 7366
#
# The number of tracks returned: 6275
#
# The number of tracks returned: 6265
#
# The number of tracks returned: 7621
#
# The number of tracks returned: 8396
#
# The number of tracks returned: 7452
#
# The number of tracks returned: 7724
#
# The number of tracks returned: 7918
#
# The number of tracks returned: 6663
#
# The number of tracks returned: 6637
#
#
# finished uploading tracks
#
# extracting features...
#
# completed feature extraction
#
# creating dataframe...
#
# saving dataframe...
#
# saving tracks...
#
# done

# %%
display_tracks?
# Out:
# Type:        module
# String form: <module 'display_tracks' from '/Users/cynashirazinejad/Documents/GitHub/Jin_Shirazinejad_et_al_branched_actin_manuscript/analysis/cmeAnalysisPostProcessingPythonScripts/display_tracks.py'>
# File:        ~/Documents/GitHub/Jin_Shirazinejad_et_al_branched_actin_manuscript/analysis/cmeAnalysisPostProcessingPythonScripts/display_tracks.py
# Docstring:
# module(name[, doc])
#
# Create a module object.
# The name must be a string; the optional doc argument can have any type.

# %%
display_tracks.cluster_with_existing_model(analysis_metadata.item().get('path_outputs'),
                            'df_ada_merged_features')
# Out:
# saving dataframe...
#
# done
#        lifetime  max_int_ap2  max_int_dnm2  dist_traveled_ap2  \
# 0         209.0  1013.148525    552.713933          19.933012
# 1         202.0   894.249101    548.768087          13.452952
# 2         199.0   920.902337    491.017736          11.149507
# 3         197.0  1522.927627   1472.756604           8.861619
# 4         196.0  1313.707712    695.651290           7.742960
# ...         ...          ...           ...                ...
# 95120       2.0    20.371898     14.543122           2.257600
# 95121       2.0    26.545835     18.728653           1.381754
# 95122       2.0    30.679552     25.954461           5.877021
# 95123       2.0    27.137146     25.832401           1.715235
# 95124       2.0    20.191605     16.443930           4.121103
#
#        dist_traveled_dnm2  max_dist_between_ap2_dnm2    md_ap2   md_dnm2  \
# 0               18.402473                   3.188439  0.361960  0.570035
# 1                9.520588                   5.468989  0.372285  0.850422
# 2                8.785578                   2.881277  0.231291  0.607379
# 3                7.629581                   3.036999  0.275162  0.611874
# 4               10.954841                   2.860498  0.219819  0.557288
# ...                   ...                        ...       ...       ...
# 95120            1.708728                   4.794535  1.340784  2.136954
# 95121            4.299297                   3.841336  2.128264  1.911551
# 95122            4.372818                   4.143621  1.489194  1.151058
# 95123            5.036993                   3.466281  1.797761  0.855427
# 95124            3.153574                   4.505754  1.963514  1.039720
#
#        time_to_peak_ap2  time_to_peak_dnm2  ...  number_of_tags  \
# 0                 201.0              130.0  ...             3.0
# 1                 173.0              180.0  ...             3.0
# 2                 127.0              145.0  ...             3.0
# 3                 137.0              155.0  ...             3.0
# 4                 168.0               74.0  ...             3.0
# ...                 ...                ...  ...             ...
# 95120               5.0                7.0  ...             3.0
# 95121               5.0                0.0  ...             3.0
# 95122               5.0                7.0  ...             3.0
# 95123               5.0                6.0  ...             3.0
# 95124               5.0                7.0  ...             3.0
#
#        cell_line_tags  current_tracked_channels  experiment_type  \
# 0      ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 1      ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 2      ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 3      ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 4      ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# ...               ...                       ...              ...
# 95120  ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 95121  ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 95122  ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 95123  ap2-dnm2-arpc3                  ap2-dnm2         wildtype
# 95124  ap2-dnm2-arpc3                  ap2-dnm2         wildtype
#
#        cell_condition  framerate    date       PC-0      PC-1  gmm_predictions
# 0        no-treatment         1s  200722  11.658500 -4.847125                0
# 1        no-treatment         1s  200722  10.140844 -5.995235                0
# 2        no-treatment         1s  200722   8.932092 -6.313098                0
# 3        no-treatment         1s  200722  10.606080 -6.094837                0
# 4        no-treatment         1s  200722   9.714568 -4.815369                0
# ...               ...        ...     ...        ...       ...              ...
# 95120    no-treatment         1s  200819  -6.842034  2.036463                3
# 95121    no-treatment         1s  200819  -7.641205  6.935307                3
# 95122    no-treatment         1s  200819  -6.231037  1.434207                3
# 95123    no-treatment         1s  200819  -6.517433  1.967509                3
# 95124    no-treatment         1s  200819  -6.596895  1.953444                3
#
# [95125 rows x 44 columns]

# %%
df_ada_merged_features
# Out:
#       lifetime         max_int_ap2        max_int_dnm2   dist_traveled_ap2  \
# 0        209.0  1013.1485253933919   552.7139333004802  19.933012015660953
# 1        202.0   894.2491011221164   548.7680869703687  13.452951691920319
# 2        199.0   920.9023370133892   491.0177359001319  11.149506754019045
# 3        197.0  1522.9276268746607  1472.7566036303167   8.861619473901422
# 4        196.0   1313.707711733558   695.6512899941846  7.7429596804257566
# ...        ...                 ...                 ...                 ...
# 95120      2.0  20.371898096697755  14.543122248428194   2.257599758232285
# 95121      2.0  26.545835239754254  18.728652970622107  1.3817543838367965
# 95122      2.0  30.679552189472272   25.95446134680785     5.8770207544381
# 95123      2.0  27.137145826404005  25.832400983443083  1.7152347198647262
# 95124      2.0   20.19160454943573  16.443929922147042   4.121102933899732
#
#        dist_traveled_dnm2 max_dist_between_ap2_dnm2               md_ap2  \
# 0       18.40247319838401        3.1884391464924975  0.36195985881085974
# 1       9.520587648395248         5.468989346151992  0.37228519925812653
# 2       8.785577584857826         2.881276819635611    0.231291066304848
# 3       7.629580737901215        3.0369987996188046  0.27516172782612536
# 4      10.954841420401717         2.860497831564555  0.21981900955470857
# ...                   ...                       ...                  ...
# 95120  1.7087280062357573         4.794534858624545   1.3407843405223034
# 95121   4.299297343065756         3.841336013298063    2.128263693872985
# 95122   4.372817561488739        4.1436209282475485   1.4891940728214246
# 95123   5.036992675116289         3.466281163913156     1.79776122323737
# 95124  3.1535738171219667         4.505754036942951   1.9635141365906406
#
#                   md_dnm2 time_to_peak_ap2 time_to_peak_dnm2  ...  \
# 0      0.5700346183484054            201.0             130.0  ...
# 1      0.8504216120195699            173.0             180.0  ...
# 2       0.607378624761824            127.0             145.0  ...
# 3      0.6118735985700916            137.0             155.0  ...
# 4      0.5572883032830082            168.0              74.0  ...
# ...                   ...              ...               ...  ...
# 95120  2.1369540047307862              5.0               7.0  ...
# 95121   1.911550749327698              5.0               0.0  ...
# 95122  1.1510579029719095              5.0               7.0  ...
# 95123  0.8554266609208848              5.0               6.0  ...
# 95124  1.0397197192207797              5.0               7.0  ...
#
#        fraction_peak_dnm2 cmeAnalysis_dynamin2_prediction experiment_number  \
# 0       0.593607305936073                             1.0               8.0
# 1      0.8490566037735849                             1.0               8.0
# 2        0.69377990430622                             1.0               8.0
# 3       0.748792270531401                             1.0               8.0
# 4      0.3592233009708738                             1.0               8.0
# ...                   ...                             ...               ...
# 95120  0.5833333333333334                             0.0              20.0
# 95121                 0.0                             0.0              20.0
# 95122  0.5833333333333334                             0.0              20.0
# 95123                 0.5                             0.0              20.0
# 95124  0.5833333333333334                             0.0              20.0
#
#       number_of_tags  cell_line_tags current_tracked_channels experiment_type  \
# 0                3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 1                3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 2                3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 3                3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 4                3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# ...              ...             ...                      ...             ...
# 95120            3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 95121            3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 95122            3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 95123            3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
# 95124            3.0  ap2-dnm2-arpc3                 ap2-dnm2        wildtype
#
#       cell_condition framerate    date
# 0       no-treatment        1s  200722
# 1       no-treatment        1s  200722
# 2       no-treatment        1s  200722
# 3       no-treatment        1s  200722
# 4       no-treatment        1s  200722
# ...              ...       ...     ...
# 95120   no-treatment        1s  200819
# 95121   no-treatment        1s  200819
# 95122   no-treatment        1s  200819
# 95123   no-treatment        1s  200819
# 95124   no-treatment        1s  200819
#
# [95125 rows x 41 columns]

# %%
detect_peaks.find_single_peaks_using_existing_model(analysis_metadata.item().get('path_outputs'),
                                                    'df_ada_merged_features',
                                                    'merged_all_valid_ada_tracks')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-019b289405c7> in <module>
# ----> 1 detect_peaks.find_single_peaks_using_existing_model(analysis_metadata.item().get('path_outputs'),
#       2                                                     'df_ada_merged_features',
#       3                                                     'merged_all_valid_ada_tracks')
#
# NameError: name 'detect_peaks' is not defined
